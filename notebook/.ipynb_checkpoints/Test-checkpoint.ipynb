# %%
# %load_ext jupyter_ai
# Out:
# The jupyter_ai extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
# %%ai gpt2
# Write a Python function to fetch JSON data from an API
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'gpt2', 'Write a Python function to fetch JSON data from an API\n')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
